# %%
from gensim.models import Word2Vec 
from nltk.cluster import KMeansClusterer
import nltk 
from sklearn import cluster
from sklearn import metrics
 
# training data
 
sentences = [['this', 'is', 'the', 'good', 'machine', 'learning', 'book'],
            ['this', 'is',  'another', 'book'],
            ['one', 'more', 'book'],
            ['this', 'is', 'the', 'new', 'post'],
          ['this', 'is', 'about', 'machine', 'learning', 'post'],  
            ['and', 'this', 'is', 'the', 'last', 'post']]
 
 
# training model
model = Word2Vec(sentences, min_count=1)
 
# get vector data
X = model.wv.key_to_index
print ("X")
print (X)
 
print (model.wv.similarity('this', 'is'))
 
print (model.wv.similarity('post', 'book'))
 
print (model.wv.most_similar(positive=['machine'], negative=[], topn=2))
print (list(model.wv.key_to_index))
 
print (len(list(model.wv.key_to_index))) 
 
NUM_CLUSTERS=3

kmeans = cluster.KMeans(n_clusters=NUM_CLUSTERS)
kmeans.fit(model.wv.vectors)
 
labels = kmeans.labels_
centroids = kmeans.cluster_centers_
 
print ("Cluster id labels for inputted data")
print (labels)
print ("Centroids data")
print (centroids)
 
print ("Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):")
print (kmeans.score(model.wv.vectors))
 
silhouette_score = metrics.silhouette_score(model.wv.vectors, labels, metric='euclidean')
 
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# X
# {'is': 0, 'this': 1, 'post': 2, 'book': 3, 'the': 4, 'learning': 5, 'machine': 6, 'last': 7, 'and': 8, 'about': 9, 'new': 10, 'more': 11, 'one': 12, 'another': 13, 'good': 14}
# -0.01083917
# -0.013514936
# [('post', 0.145950585603714), ('new', 0.05048205703496933)]
# ['is', 'this', 'post', 'book', 'the', 'learning', 'machine', 'last', 'and', 'about', 'new', 'more', 'one', 'another', 'good']
# 15
# Cluster id labels for inputted data
# [2 1 1 1 1 1 0 1 1 2 0 1 0 0 1]
# Centroids data
# [[ 9.4418263e-04 -4.3264055e-04  2.1388750e-03 -5.1066331e-03
#   -2.1557687e-03 -1.2636782e-03 -1.8306116e-03  1.5481131e-03
#   -4.3184403e-04 -4.1452595e-03  7.9627184e-04 -7.0983253e-04
#   -2.3817667e-03 -9.7938126e-04  7.1010878e-04  6.8256404e-04
#    5.0066849e-03  2.7900049e-03  2.8184543e-03 -6.4372225e-03
#   -1.2873425e-05 -2.4870303e-04  6.1770347e-03  3.0643414e-03
#    7.5393281e-04  5.6589576e-03 -5.1176907e-03 -1.7298396e-03
#    1.6408915e-03  4.2498973e-03  6.1442773e-04  4.2563449e-03
#    4.2967149e-03  1.4130271e-03  4.3384329e-04 -1.7473609e-03
#   -5.2153254e-03 -2.3362869e-03 -2.2565911e-03 -2.8848746e-03
#    3.5530649e-04 -8.6115743e-04  1.0875314e-03  8.1085355e-04
